# %%
# !pip install librosa==0.10.2.
# !pip install matplotlib
# !pip install soundfile
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Invalid requirement: 'librosa==0.10.2.': Expected end or semicolon (after version specifier)
#     librosa==0.10.2.
#            ~~~~~~~~^
# Requirement already satisfied: matplotlib in c:\users\digvijay vyas\appdata\local\programs\python\python313\lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\digvijay vyas\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\digvijay vyas\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\digvijay vyas\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\digvijay vyas\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\digvijay vyas\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.3.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\digvijay vyas\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\digvijay vyas\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\digvijay vyas\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\digvijay vyas\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\digvijay vyas\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: soundfile in c:\users\digvijay vyas\appdata\local\programs\python\python313\lib\site-packages (0.13.1)
# Requirement already satisfied: cffi>=1.0 in c:\users\digvijay vyas\appdata\local\programs\python\python313\lib\site-packages (from soundfile) (2.0.0)
# Requirement already satisfied: numpy in c:\users\digvijay vyas\appdata\local\programs\python\python313\lib\site-packages (from soundfile) (2.3.3)
# Requirement already satisfied: pycparser in c:\users\digvijay vyas\appdata\local\programs\python\python313\lib\site-packages (from cffi>=1.0->soundfile) (2.23)
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt
import soundfile as sf

# %%
# Load audio file
y, sr = librosa.load("D:/AI/Song scaler/file1.mp3")

# %%
# --- Step 1: Detect pitches and chroma features ---
chroma = librosa.feature.chroma_stft(y=y, sr=sr)
chroma_mean = chroma.mean(axis=1)

# %%
chroma_mean
# Out:
# array([0.4998606 , 0.60834295, 0.42504236, 0.3886874 , 0.3711709 ,
#        0.43837583, 0.38273472, 0.4122189 , 0.46533063, 0.52140415,
#        0.65382975, 0.47277325], dtype=float32)

# %%
# Map chroma to note names
note_names = ['C', 'C#', 'D', 'D#', 'E', 'F', 
              'F#', 'G', 'G#', 'A', 'A#', 'B']

# %%
# Find the most dominant pitch class
dominant_note = note_names[np.argmax(chroma_mean)]
print(f"Detected dominant note: {dominant_note}")
# Out:
# Detected dominant note: A#

# %%
# --- Step 2: Estimate key (major/minor) ---
# Librosa has a built-in key estimation in v0.10+
try:
    key = librosa.key(y, sr=sr)
    print(f"Estimated key: {key}")
except:
    print("Key estimation requires Librosa v0.10+; upgrade if needed.")
# Out:
# Key estimation requires Librosa v0.10+; upgrade if needed.

# %%
print(librosa.__version__)
# Out:
# 0.11.0

# %%
# --- Step 3: Shift scale (transpose) ---
# Example: shift up by 2 semitones
y_shifted = librosa.effects.pitch_shift(y=y, sr=sr, n_steps=2)

# Save shifted audio
sf.write("song_shifted.wav", y_shifted, sr)

print("Shifted audio saved as song_shifted.wav")
# Out:
# Shifted audio saved as song_shifted.wav
